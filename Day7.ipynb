# %%
import numpy as np

# %%
arr1 = np.array([1,2,3])
arr2 = np. array([[10],[20],[30]])
result = arr1 + arr2
result
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5])

result = arr1 + arr2
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 arr1 = np.array([1, 2, 3])
#       2 arr2 = np.array([4, 5])
# ----> 4 result = arr1 + arr2
#       5 result
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %%
from PIL import Image

# %%
img = Image.open('D:/Assets/A2/download.png')

# %%
img_arr = np.array(img)

# %%
gray_img_arr = np.mean(img_arr,axis=2)

# %%
gray_img = Image.fromarray(gray_img_arr.astype('uint8'))

# %%
gray_img
# Out:
# <PIL.Image.Image image mode=L size=900x1602>
